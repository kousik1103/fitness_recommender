# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = "Personalized_Fitness_Recommender_Dataset.csv" 
df = pd.read_csv(file_path)

# %%
# Perform EDA
print("Shape of the Dataset:", df.shape)

print("\nColumn Names and Data Types:")
print(df.dtypes)

print("\nMissing Values:")
print(df.isnull().sum())

print("\nSummary Statistics (Numerical Columns):")
print(df.describe())

print("\nUnique Values in Categorical Columns:")
categorical_columns = df.select_dtypes(include=['object']).columns
for col in categorical_columns:
    print(f"{col}: {df[col].nunique()} unique values")

print("\nSample Data:")
print(df.head())
# Out:
# Shape of the Dataset: (500, 12)
#
# Column Names and Data Types:
# UserID                  object
# Age                      int64
# Gender                  object
# FitnessGoal             object
# ActivityPreference      object
# CurrentFitnessLevel     object
# BodyMassIndex          float64
# HealthConditions        object
# TimeAvailability         int64
# DietPreference          object
# RecommendedWorkout      object
# RecommendedDiet         object
# dtype: object
#
# Missing Values:
# UserID                   0
# Age                      0
# Gender                   0
# FitnessGoal              0
# ActivityPreference       0
# CurrentFitnessLevel      0
# BodyMassIndex            0
# HealthConditions       128
# TimeAvailability         0
# DietPreference           0
# RecommendedWorkout       0
# RecommendedDiet          0
# dtype: int64
#
# Summary Statistics (Numerical Columns):
#               Age  BodyMassIndex  TimeAvailability
# count  500.000000     500.000000        500.000000
# mean    39.716000      24.216200          5.590000
# std     12.902414       3.312029          2.960309
# min     18.000000      18.500000          1.000000
# 25%     29.000000      21.375000          3.000000
# 50%     40.000000      24.200000          6.000000
# 75%     51.000000      27.100000          8.000000
# max     60.000000      30.000000         10.000000
#
# Unique Values in Categorical Columns:
# UserID: 500 unique values
# Gender: 3 unique values
# FitnessGoal: 4 unique values
# ActivityPreference: 4 unique values
# CurrentFitnessLevel: 3 unique values
# HealthConditions: 3 unique values
# DietPreference: 4 unique values
# RecommendedWorkout: 4 unique values
# RecommendedDiet: 4 unique values
#
# Sample Data:
#   UserID  Age      Gender  FitnessGoal ActivityPreference CurrentFitnessLevel  \
# 0  U0001   58        Male  Weight Loss               Yoga            Advanced
# 1  U0002   36  Non-Binary  Muscle Gain  Strength Training        Intermediate
# 2  U0003   45  Non-Binary  Weight Loss             Cardio        Intermediate
# 3  U0004   45        Male    Endurance  Strength Training            Beginner
# 4  U0005   31  Non-Binary  Muscle Gain  Strength Training            Beginner
#
#    BodyMassIndex HealthConditions  TimeAvailability  DietPreference  \
# 0           27.9     Hypertension                 7  Non-Vegetarian
# 1           29.1         Diabetes                 3      Vegetarian
# 2           21.5           Asthma                 1            Keto
# 3           18.6     Hypertension                 9           Vegan
# 4           19.4              NaN                 7           Vegan
#
#   RecommendedWorkout  RecommendedDiet
# 0               Yoga     High-Protein
# 1               HIIT         Low-Carb
# 2           Swimming  Calorie-Deficit
# 3               HIIT         Low-Carb
# 4      Weightlifting  Calorie-Deficit

# %%
plt.figure(figsize=(6, 6))
gender_counts = df['Gender'].value_counts()
gender_counts.plot(kind='pie', autopct='%1.1f%%', colors=['lightblue', 'pink'], startangle=90)
plt.title("Gender Distribution")
plt.ylabel("")  # Hide y-label for pie chart
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Age'], kde=True, bins=20, color='blue')
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()
# Out:
# C:\Users\kousi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
